# %%
#hide
from fast_tfrs.core import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-6e5a0d184583> in <module>()
#       1 #hide
# ----> 2 from fast_tfrs.core import *
#
# ModuleNotFoundError: No module named 'fast_tfrs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # nbdev_colab
#
# > This is a starter repository for using Google Colab completely for `nbdev`

# %% [markdown]
# * **NOTE:** I cannot get past the tests with the notebooks. If someone knows what I may be doing wrong please put in a PR :)

# %% [markdown]
# ## Install

# %%
pip install fast_tfrs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement fast_tfrs (from versions: none)
# ERROR: No matching distribution found for fast_tfrs

# %% [markdown]
# `pip install your_project_name`

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
